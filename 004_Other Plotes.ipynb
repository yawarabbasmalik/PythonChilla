# %% [markdown]
# # Line Plot with Multi-Facets

# %% [markdown]
# The Bar plot is mostly used for Plotting of both numeric and categorical data

# %%
#importing libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
#importing data
clean_data = pd.read_csv("Chilla_data2_for_plots.csv")
clean_data.head()
# Out:
#    Gender  Location    Age Qualification_completed    field_of_study  \
# 0    Male  Pakistan  36-40                 Masters  Natural Sciences
# 1    Male  Pakistan  26-30               Bachelors             CS/IT
# 2    Male  Pakistan  31-35                 Masters       Enginnering
# 3  Female  Pakistan  31-35                 Masters             CS/IT
# 4  Female  Pakistan  26-30                 Masters       Enginnering
#
#          Purpose_for_chilla What are you? Blood group   \
# 0     to boost my skill set     Unemplyed           B+
# 1     to boost my skill set       Student           B+
# 2  Switch my field of study      Employed           B+
# 3     to boost my skill set      Employed           O+
# 4     to boost my skill set       Student           A-
#
#   Which mobile sim do you use Prepaid or Postpaid  ...  \
# 0                      U-fone             Prepaid  ...
# 1                      U-fone             Prepaid  ...
# ...

# %%
# Color Changing in Bar Plot
sns.relplot(x = "Age (years)-Float/Int", y = "What are you?",
            hue = "Gender", data = clean_data, palette="Accent_r",
            kind = "line",
            height = 5, aspect=0.75, facet_kws=dict(sharex=False),
           )
plt.show()

# %% [markdown]
# # Displot (Histogram)

# %%
sns.displot(
    data = clean_data, x="Age (years)-Float/Int", col="What are you?", row="Gender",
    binwidth=3, height=3, facet_kws=dict(margin_titles=True),
)

# %% [markdown]
# # Grouped barplots¶

# %%
g = sns.catplot(
    data = clean_data, x="Age (years)-Float/Int", y="What are you?", hue="Gender",
    kind="bar", ci=None, palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("", "Profession")
g.legend.set_title("Python Chilla Students Data")

# %% [markdown]
# # Joint Plot

# %%
g = sns.jointplot(
    data=clean_data,
    x="Age (years)-Float/Int", y="How many hours you code a day? (int) e.g: 5,4,3", hue="Gender",
    kind="kde",
)
