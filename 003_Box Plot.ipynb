# %% [markdown]
# # Box Plot

# %% [markdown]
# The Bar plot is mostly used for Plotting of both numeric and categorical data

# %%
#importing libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
#importing data
clean_data = pd.read_csv("Chilla_data2_for_plots.csv")
clean_data.head()
# Out:
#    Gender  Location    Age Qualification_completed    field_of_study  \
# 0    Male  Pakistan  36-40                 Masters  Natural Sciences
# 1    Male  Pakistan  26-30               Bachelors             CS/IT
# 2    Male  Pakistan  31-35                 Masters       Enginnering
# 3  Female  Pakistan  31-35                 Masters             CS/IT
# 4  Female  Pakistan  26-30                 Masters       Enginnering
#
#          Purpose_for_chilla What are you? Blood group   \
# 0     to boost my skill set     Unemplyed           B+
# 1     to boost my skill set       Student           B+
# 2  Switch my field of study      Employed           B+
# 3     to boost my skill set      Employed           O+
# 4     to boost my skill set       Student           A-
#
#   Which mobile sim do you use Prepaid or Postpaid  ...  \
# 0                      U-fone             Prepaid  ...
# 1                      U-fone             Prepaid  ...
# ...

# %%
#drawing a boxplot
sns.boxplot(x = "Your favorite programming language?", 
            y = "How many hours you code a day? (int) e.g: 5,4,3", 
            data = clean_data)
plt.show()

# %% [markdown]
# # Box Plot Style

# %%
sns.set(style='whitegrid')
#drawing a boxplot
sns.boxplot(x = "Your favorite programming language?", 
            y = "How many hours you code a day? (int) e.g: 5,4,3", 
            data = clean_data)
plt.show()

# %% [markdown]
# # Categoriazation in Bar Plot

# %%
sns.set(style='whitegrid')
#drawing a boxplot
sns.boxplot(x = "Your favorite programming language?", 
            y = "How many hours you code a day? (int) e.g: 5,4,3", 
            data = clean_data, palette="Accent_r",
           saturation=2)
plt.show()

# %%
clean_data.describe()
# Out:
#        Age (years)-Float/Int  Your Weight in kg? (float)  \
# count             375.000000                  375.000000
# mean               27.576933                   69.321147
# std                 7.224460                   16.264434
# min                 0.000000                    7.000000
# 25%                24.000000                   58.050000
# 50%                27.000000                   68.300000
# 75%                31.000000                   78.500000
# max                90.000000                  161.000000
#
#        Height in cm? Freelancer- (Float)  \
# count                         375.000000
# mean                          162.679282
# std                           172.246844
# min                             0.000000
# 25%                           158.000000
# 50%                           169.000000
# 75%                           175.225000
# max                          1661.160000
#
#        How many hours you code a day? (int) e.g: 5,4,3  \
# ...

# %% [markdown]
# # Important Notes
# - Categorical Data (Attributes) are mostly drawn on x-axis.
# - Numeric Data (Attributes) are mostly drawn on y-axis.
# - Numeric Data (Attributes) are never drwan using "Hue".
# - The box contains the value of interquartile range.
# - The center bar in the box represents "Median".
# - The Right/ Left or sometime Upper/Lower bars represents the maximum and minimum outlier data.
# - The dots represents the outliers

# %%
sns.set(style='whitegrid')
#drawing a boxplot
sns.boxplot(x = clean_data["Age (years)-Float/Int"])
plt.show()

# %% [markdown]
# # Color Picking

# %%
sns.set(style='whitegrid')
#drawing a boxplot
sns.boxplot(x = "Your favorite programming language?", 
            y = "How many hours you code a day? (int) e.g: 5,4,3", 
            data = clean_data, color="#09ebdc")
plt.show()

# %% [markdown]
# # Showing Means in the Box Plot

# %%
sns.set(style='whitegrid')
#drawing a boxplot
sns.boxplot(x = "Your favorite programming language?", 
            y = "How many hours you code a day? (int) e.g: 5,4,3",
            showmeans = True,
            data = clean_data, color="#09ebdc")
plt.show()

# %% [markdown]
# # Setting Mean Properties in Box Plot

# %%
sns.set(style='whitegrid')
#drawing a boxplot
sns.boxplot(x = "Your favorite programming language?", 
            y = "How many hours you code a day? (int) e.g: 5,4,3",
            showmeans = True,
            meanprops = { "marker" : "+",
                         "markersize" : "10",
                         "markeredgecolor" : "#464694"},
            data = clean_data, color="#09ebdc")
plt.show()

# %% [markdown]
# # Adusting Sizes and Labels

# %%
sns.set(style='whitegrid')
#drawing a boxplot
sns.boxplot(x = "Your favorite programming language?", 
            y = "How many hours you code a day? (int) e.g: 5,4,3",
            showmeans = True,
            meanprops = { "marker" : "+",
                         "markersize" : "10",
                         "markeredgecolor" : "#464694"},
            data = clean_data, color="#09ebdc")

plt.xlabel("Programmers Lanaguges", size = 12)
plt.ylabel("Programmers Practice Each Day", size = 12)
plt.title("Chilla Programmers Stats", size = 18, weight = "bold")
plt.show()
