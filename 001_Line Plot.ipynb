# %% [markdown]
# # Line Plot

# %% [markdown]
# The Line plot is mostly used for Plotting of numeric values rather than categorical values

# %%
#importing libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
#importing data
clean_data = pd.read_csv("Chilla_data2_for_plots.csv")
clean_data.head()
# Out:
#    Gender  Location    Age Qualification_completed    field_of_study  \
# 0    Male  Pakistan  36-40                 Masters  Natural Sciences
# 1    Male  Pakistan  26-30               Bachelors             CS/IT
# 2    Male  Pakistan  31-35                 Masters       Enginnering
# 3  Female  Pakistan  31-35                 Masters             CS/IT
# 4  Female  Pakistan  26-30                 Masters       Enginnering
#
#          Purpose_for_chilla What are you? Blood group   \
# 0     to boost my skill set     Unemplyed           B+
# 1     to boost my skill set       Student           B+
# 2  Switch my field of study      Employed           B+
# 3     to boost my skill set      Employed           O+
# 4     to boost my skill set       Student           A-
#
#   Which mobile sim do you use Prepaid or Postpaid  ...  \
# 0                      U-fone             Prepaid  ...
# 1                      U-fone             Prepaid  ...
# ...

# %%
#drawing a lineplot
sns.lineplot(x = "Age (years)-Float/Int", y = "Height in cm? Freelancer- (Float)", data = clean_data)
plt.show()

# %% [markdown]
# # Adding Title

# %%
#drawing a lineplot
sns.lineplot(x = "Age (years)-Float/Int", y = "Height in cm? Freelancer- (Float)", data = clean_data)
plt.title("Python Chilla Class Age & Height Stats")
plt.show()

# %% [markdown]
# # Adding Limits x&y

# %%
#Adding limits
sns.lineplot(x = "Age (years)-Float/Int", y = "Height in cm? Freelancer- (Float)", data = clean_data)
plt.title("Python Chilla Class Age & Height Stats")
plt.xlim(5)
plt.ylim(100)
plt.show()

# %% [markdown]
# # Style Setting

# %%
sns.set_style(style=None, rc=None)

# %%
# Setting Style
sns.lineplot(x = "Age (years)-Float/Int", y = "Height in cm? Freelancer- (Float)", data = clean_data)
plt.title("Python Chilla Class Age & Height Stats")
sns.set_style("dark")
plt.show()

# %% [markdown]
# # Size Adjustment

# %%
#Setting size of the Plot
plt.figure(figsize=(8, 6))

sns.lineplot(x = "Age (years)-Float/Int", y = "Height in cm? Freelancer- (Float)", data = clean_data)
plt.title("Python Chilla Class Age & Height Stats")
plt.show()
